# %%
import socket
import time

# %%
host, port = "127.0.0.1", 64738 #################################################
sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM) #################################################
sock.connect((host, port)) #################################################

startPos = [0, 0, 0]
while True:
    time.sleep(0.5)
    startPos[0] += 1
    posString = ",".join(map(str, startPos))
    print(posString)

    sock.sendall(posString.encode("UTF-8")) #################################################
    recievedData = sock.recv(1024).decode("UTF-8") #################################################
    print(recievedData)
# Out:
# 1,0,0
# Message recieved
# 2,0,0
# Message recieved
# 3,0,0
# Message recieved
# 4,0,0
# Message recieved
# 5,0,0
# Message recieved
# 6,0,0
# Message recieved
# 7,0,0
# Message recieved
# 8,0,0
# Message recieved
# 9,0,0
# Message recieved
# 10,0,0
# Message recieved
# 11,0,0
# Message recieved
# 12,0,0
# Message recieved
# 13,0,0
# Message recieved
# 14,0,0
# Message recieved
# 15,0,0
# Message recieved
# 16,0,0
# Message recieved
# 17,0,0
# Message recieved
# 18,0,0
# Message recieved
# 19,0,0
# Message recieved
# 20,0,0
# Message recieved
# 21,0,0
# Message recieved
# 22,0,0
# Message recieved
# 23,0,0
# Message recieved
# 24,0,0
# Message recieved
# 25,0,0
# Message recieved
# 26,0,0
# Message recieved
# 27,0,0
# Message recieved
# 28,0,0
# Message recieved
# 29,0,0
# Message recieved
# 30,0,0
# Message recieved
# 31,0,0
# Message recieved
# 32,0,0
# Message recieved
# 33,0,0
# Message recieved
# 34,0,0
# Message recieved
# 35,0,0
# Message recieved
# 36,0,0
# Message recieved
# 37,0,0
# Message recieved
# 38,0,0
# Message recieved
# 39,0,0
# Message recieved
# 40,0,0
# Message recieved
# 41,0,0
# Message recieved
# 42,0,0
# Message recieved
# 43,0,0
# Message recieved
# 44,0,0
# Message recieved
# 45,0,0
# Message recieved
# 46,0,0
# Message recieved
# 47,0,0
# Message recieved
# 48,0,0
# Message recieved
# 49,0,0
# Message recieved
# 50,0,0
# Message recieved
# 51,0,0
# Message recieved
# 52,0,0
# Message recieved
# 53,0,0
# Message recieved
# 54,0,0
# Message recieved
# 55,0,0
# Message recieved
# 56,0,0
# Message recieved
# 57,0,0
# Message recieved
# 58,0,0
# Message recieved
# 59,0,0
# Message recieved
# 60,0,0
# Message recieved
# 61,0,0
# Message recieved
# 62,0,0
# Message recieved
# 63,0,0
# Message recieved
# 64,0,0
# Message recieved
# 65,0,0
# Message recieved
# 66,0,0
# Message recieved
# 67,0,0
# Message recieved
# 68,0,0
# Message recieved
# 69,0,0
# Message recieved
# 70,0,0
# Message recieved
# 71,0,0
# Message recieved
# 72,0,0
# Message recieved
# 73,0,0
# Message recieved
# 74,0,0
# Message recieved
# 75,0,0
# Message recieved
# 76,0,0
# Message recieved
# 77,0,0
# Message recieved
# 78,0,0
# Message recieved
# 79,0,0
# Message recieved
# 80,0,0
# Message recieved
# 81,0,0
# Message recieved
# 82,0,0
# Message recieved
# 83,0,0
# Message recieved
# 84,0,0
# Message recieved
# 85,0,0
# Message recieved
# 86,0,0
# Message recieved
# 87,0,0
# Message recieved
# 88,0,0
# Message recieved
# 89,0,0
# Message recieved
# 90,0,0
# Message recieved
# 91,0,0
# Message recieved
# 92,0,0
# Message recieved
# 93,0,0
# Message recieved
# 94,0,0
# Message recieved
# 95,0,0
# Message recieved
# 96,0,0
# Message recieved
# 97,0,0
# Message recieved
# 98,0,0
# Message recieved
# 99,0,0
# Message recieved
# 100,0,0
# Message recieved
# 101,0,0
# Message recieved
# 102,0,0
# Message recieved
# 103,0,0
# Message recieved
# 104,0,0
# Message recieved
# 105,0,0
# Message recieved
# 106,0,0
# Message recieved
# 107,0,0
# Message recieved
# 108,0,0
# Message recieved
# 109,0,0
# Message recieved
# 110,0,0
# Message recieved
# 111,0,0
# Message recieved
# 112,0,0
# Message recieved
# 113,0,0
# Message recieved
# 114,0,0
# Message recieved
# 115,0,0
# Message recieved
# 116,0,0
# Message recieved
# 117,0,0
# Message recieved
# 118,0,0
# Message recieved
# 119,0,0
# Message recieved
# 120,0,0
# Message recieved
# 121,0,0
# Message recieved
# 122,0,0
# Message recieved
# 123,0,0
# Message recieved
# 124,0,0
# Message recieved
# 125,0,0
# Message recieved
# 126,0,0
# Message recieved
# 127,0,0
# Message recieved
# 128,0,0
# Message recieved
# 129,0,0
# Message recieved
# 130,0,0
# Message recieved
# 131,0,0
# Message recieved
# 132,0,0
# Message recieved
# 133,0,0
# Message recieved
# 134,0,0
# Message recieved
# 135,0,0
# Message recieved
# 136,0,0
# Message recieved
# 137,0,0
# Message recieved
# 138,0,0
# Message recieved
# 139,0,0
# Message recieved
# 140,0,0
# Message recieved
# 141,0,0
# Message recieved
# 142,0,0
# Message recieved
# 143,0,0
# Message recieved
# 144,0,0
# Message recieved
# 145,0,0
# Message recieved
# 146,0,0
# Message recieved
# 147,0,0
# Message recieved
# 148,0,0
# Message recieved
# 149,0,0
# Message recieved
# 150,0,0
# Message recieved
# 151,0,0
# Message recieved
# 152,0,0
# Message recieved
# 153,0,0
# Message recieved
# 154,0,0
# Message recieved
# 155,0,0
# Message recieved
# 156,0,0
# Message recieved
# 157,0,0
# Message recieved
# 158,0,0
# Message recieved
# 159,0,0
# Message recieved
# 160,0,0
# Message recieved
# 161,0,0
# Message recieved
# 162,0,0
# Message recieved
# 163,0,0
# Message recieved
# 164,0,0
# Message recieved
# 165,0,0
# Message recieved
# 166,0,0
# Message recieved
# 167,0,0
# Message recieved
# 168,0,0
# Message recieved
# 169,0,0
# Message recieved
# 170,0,0
# Message recieved
# 171,0,0
# Message recieved
# 172,0,0
# Message recieved
# 173,0,0
# Message recieved
# 174,0,0
# Message recieved
# 175,0,0
# Message recieved
# 176,0,0
# Message recieved
# 177,0,0
# Message recieved
# 178,0,0
# Message recieved
# 179,0,0
# Message recieved
# 180,0,0
# Message recieved
# 181,0,0
# Message recieved
# 182,0,0
# Message recieved
# 183,0,0
# Message recieved
# 184,0,0
# Message recieved
# 185,0,0
# Message recieved
# 186,0,0
# Message recieved
# 187,0,0
# Message recieved
# 188,0,0
# Message recieved
# 189,0,0
# Message recieved
# 190,0,0
# Message recieved
# 191,0,0
# Message recieved
# 192,0,0
# Message recieved
# 193,0,0
# Message recieved
# 194,0,0
# Message recieved
# 195,0,0
# Message recieved
# 196,0,0
# Message recieved
# 197,0,0
# Message recieved
# 198,0,0
# Message recieved
# 199,0,0
# Message recieved
# 200,0,0
# Message recieved
# 201,0,0
# Message recieved
# 202,0,0
# Message recieved
# 203,0,0
# Message recieved
# 204,0,0
# Message recieved
# 205,0,0
# Message recieved
# 206,0,0
# Message recieved
# 207,0,0
# Message recieved
# 208,0,0
# Message recieved
# 209,0,0
# Message recieved
# 210,0,0
# Message recieved
# 211,0,0
# Message recieved
# 212,0,0
# Message recieved
# 213,0,0
# Message recieved
# 214,0,0
# Message recieved
# 215,0,0
# Message recieved
# 216,0,0
# Message recieved
# 217,0,0
# Message recieved
# 218,0,0
# Message recieved
# 219,0,0
# Message recieved
# 220,0,0
# Message recieved
# 221,0,0
# Message recieved
# 222,0,0
# Message recieved
# 223,0,0
# Message recieved
# 224,0,0
# Message recieved
# 225,0,0
# Message recieved
# 226,0,0
# Message recieved
# 227,0,0
# Message recieved
# 228,0,0
# Message recieved
# 229,0,0
# Message recieved
# 230,0,0
# Message recieved
# 231,0,0
# Message recieved
# 232,0,0
# Message recieved
# 233,0,0
# Message recieved
# 234,0,0
# Message recieved
# 235,0,0
# Message recieved
# 236,0,0
# Message recieved
# 237,0,0
# Message recieved
# 238,0,0
# Message recieved
# 239,0,0
# Message recieved
# 240,0,0
# Message recieved
# 241,0,0
# Message recieved
# 242,0,0
# Message recieved
# 243,0,0
# Message recieved
# 244,0,0
# Message recieved
# 245,0,0
# Message recieved
# 246,0,0
# Message recieved
# 247,0,0
# Message recieved
# 248,0,0
# Message recieved
# 249,0,0
# Message recieved
# 250,0,0
# Message recieved
# 251,0,0
# Message recieved
# 252,0,0
# Message recieved
# 253,0,0
# Message recieved
# 254,0,0
# Message recieved
# 255,0,0
# Message recieved
# 256,0,0
# Message recieved
# 257,0,0
# Message recieved
# 258,0,0
# Message recieved
# 259,0,0
# Message recieved
# 260,0,0
# Message recieved
# 261,0,0
# Message recieved
# 262,0,0
# Message recieved
# 263,0,0
# Message recieved
# 264,0,0
# Message recieved
# 265,0,0
# Message recieved
# 266,0,0
# Message recieved
# 267,0,0
# Message recieved
# 268,0,0
# Message recieved
# 269,0,0
# Message recieved
# 270,0,0
# Message recieved
# 271,0,0
# Message recieved
# 272,0,0
# Message recieved
# 273,0,0
# Message recieved
# 274,0,0
# Message recieved
# 275,0,0
# Message recieved
# 276,0,0
# Message recieved
# 277,0,0
# Message recieved
# 278,0,0
# Message recieved
# 279,0,0
# Message recieved
# 280,0,0
# Message recieved
# 281,0,0
# Message recieved
# 282,0,0
# Message recieved
# 283,0,0
# Message recieved
# 284,0,0
# Message recieved
# 285,0,0
# Message recieved
# 286,0,0
# Message recieved
# 287,0,0
# Message recieved
# 288,0,0
# Message recieved
# 289,0,0
# Message recieved
# 290,0,0
# Message recieved
# 291,0,0
# Message recieved
# 292,0,0
# Message recieved
# 293,0,0
# Message recieved
# 294,0,0
# Message recieved
# 295,0,0
# Message recieved
# 296,0,0
# Message recieved
# 297,0,0
# Message recieved
# 298,0,0
# Message recieved
# 299,0,0
# Message recieved
# 300,0,0
# Message recieved
# 301,0,0
# Message recieved
# 302,0,0
# Message recieved
# 303,0,0
# Message recieved
# 304,0,0
# Message recieved
# 305,0,0
# Message recieved
# 306,0,0
# Message recieved
# 307,0,0
# Message recieved
# 308,0,0
# Message recieved
# 309,0,0
# Message recieved
# 310,0,0
# Message recieved
# 311,0,0
# Message recieved
# 312,0,0
# Message recieved
# 313,0,0
# Message recieved
# 314,0,0
# Message recieved
# 315,0,0
# Message recieved
# 316,0,0
# Message recieved
# 317,0,0
# Message recieved
# 318,0,0
# Message recieved
# 319,0,0
# Message recieved
# 320,0,0
# Message recieved
# 321,0,0
# Message recieved
# 322,0,0
# Message recieved
# 323,0,0
# Message recieved
# 324,0,0
# Message recieved
# 325,0,0
# Message recieved
# 326,0,0
# Message recieved
# 327,0,0
# Message recieved
# 328,0,0
# Message recieved
# 329,0,0
# Message recieved
# 330,0,0
# Message recieved
# 331,0,0
# Message recieved
# 332,0,0
# Message recieved
# 333,0,0
# Message recieved
# 334,0,0
# Message recieved
# 335,0,0
# Message recieved
# 336,0,0
# Message recieved
# 337,0,0
# Message recieved
# 338,0,0
# Message recieved
# 339,0,0
# Message recieved
# 340,0,0
# Message recieved
# 341,0,0
# Message recieved
# 342,0,0
# Message recieved
# 343,0,0
# Message recieved
# 344,0,0
# Message recieved
# 345,0,0
# Message recieved
# 346,0,0
# Message recieved
# 347,0,0
# Message recieved
# 348,0,0
# Message recieved
# 349,0,0
# Message recieved
# 350,0,0
# Message recieved
# 351,0,0
# Message recieved
# 352,0,0
# Message recieved
# 353,0,0
# Message recieved
# 354,0,0
# Message recieved
# 355,0,0
# Message recieved
# 356,0,0
# Message recieved
# 357,0,0
# Message recieved
# 358,0,0
# Message recieved
# 359,0,0
# Message recieved
# 360,0,0
# Message recieved
# 361,0,0
# Message recieved
# 362,0,0
# Message recieved
# 363,0,0
# Message recieved
# 364,0,0
# Message recieved
# 365,0,0
# Message recieved
# 366,0,0
# Message recieved
# 367,0,0
# Message recieved
# 368,0,0
# Message recieved
# 369,0,0
# Message recieved
# 370,0,0
# Message recieved
# 371,0,0
# Message recieved
# 372,0,0
# Message recieved
# 373,0,0
# Message recieved
# 374,0,0
# Message recieved
# 375,0,0
# Message recieved
# 376,0,0
# Message recieved
# 377,0,0
# Message recieved
# 378,0,0
# Message recieved
# 379,0,0
# Message recieved
# 380,0,0
# Message recieved
# 381,0,0
# Message recieved
# 382,0,0
# Message recieved
# 383,0,0
# Message recieved
# 384,0,0
# Message recieved
# 385,0,0
# Message recieved
# 386,0,0
# ---------------------------------------------------------------------------
# ConnectionAbortedError                    Traceback (most recent call last)
# c:\Users\supsu\OneDrive\Proj\Data Transfer Python\Data Transfer\Server Creation\marcus_solution.ipynb Cell 2 in <cell line: 7>()
#      <a href='vscode-notebook-cell:/c%3A/Users/supsu/OneDrive/Proj/Data%20Transfer%20Python/Data%20Transfer/Server%20Creation/marcus_solution.ipynb#W1sZmlsZQ%3D%3D?line=9'>10</a> print(posString)
#      <a href='vscode-notebook-cell:/c%3A/Users/supsu/OneDrive/Proj/Data%20Transfer%20Python/Data%20Transfer/Server%20Creation/marcus_solution.ipynb#W1sZmlsZQ%3D%3D?line=11'>12</a> sock.sendall(posString.encode("UTF-8")) #################################################
# ---> <a href='vscode-notebook-cell:/c%3A/Users/supsu/OneDrive/Proj/Data%20Transfer%20Python/Data%20Transfer/Server%20Creation/marcus_solution.ipynb#W1sZmlsZQ%3D%3D?line=12'>13</a> recievedData = sock.recv(1024).decode("UTF-8") #################################################
#      <a href='vscode-notebook-cell:/c%3A/Users/supsu/OneDrive/Proj/Data%20Transfer%20Python/Data%20Transfer/Server%20Creation/marcus_solution.ipynb#W1sZmlsZQ%3D%3D?line=13'>14</a> print(recievedData)
#
# ConnectionAbortedError: [WinError 10053] An established connection was aborted by the software in your host machine
